# %%
#importing works 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
# data loading
df=pd.read_csv("akjhdskjhkjahkjdhas")

# %%
#train  test split 
cutoff=int(len(df)*0.8)
Train=df[:cutoff]
Train=df[cutoff:]

# feature engineering 
columns=['Symbol','Date','Open', 'High', 'Low', 'Close', 'VWAP', 
                    'Vol', 'Prev. Close', 'Turnover', 'Trans.', 'Diff', 'Range', 'Diff %',
                    'Range %', 'VWAP %', '120 Days', '180 Days', '52 Weeks High',
                    '52 Weeks Low']

data=df[columns]
print(data.isnull().sum())
data=data.dropna()
data=data.drop_duplicates()

# %%
#EDA 
data.corr
